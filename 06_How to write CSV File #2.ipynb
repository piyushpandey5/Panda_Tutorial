# %% [markdown]
# # How to write CSV File

# %%
import pandas as pd

# %%
df=pd.read_csv('E:\\new1\\Book3.csv')
df
# Out:
#    ID Date          Name             Industry  inception        Revenue  \
# 0   1  Yes        Lamtone         IT Services       2009   $11,757,018
# 1   2  Yes      Stripfind  Financial Services       2010   $11,757,018
# 2   3  Yes  Concoperation              Health       2012   $11,757,018
# 3   4  Yes       Muttouch         IT Services       2013  $125,488,454
# 4   5  Yes       Techline              health       2018  $450,000,000
# 5   6  Yes        Cityace              health       2011   $45,105,454
# 6   7  Yes         kaylet              Health       2003    $5,465,451
# 7   8  Yes          helor              Health       2008  $354,787,821
# 8   9  Yes      serpaline    Government Serv.       2005   $87,875,315
#
#             Expenses    Profit  Growth
# 0  6,482,465 Dollars  45643434     30%
# 1   45412134 Dollars  55454878     45%
# 2    45315481Dollars  54464546     12%
# 3    5444812 Dollars  45456287      2%
# 4     454121 Dollars   4545454     23%
# ...

# %%
df.head()
# Out:
#    1        Lamtone         IT Services  2009   $11,757,018   \
# 0  2      Stripfind  Financial Services  2010   $11,757,018
# 1  3  Concoperation              Health  2012   $11,757,018
# 2  4       Muttouch         IT Services  2013  $125,488,454
# 3  5       Techline              health  2018  $450,000,000
# 4  6        Cityace              health  2011   $45,105,454
#
#   6,482,465 Dollars  45643434  30%
# 0  45412134 Dollars  55454878  45%
# 1   45315481Dollars  54464546  12%
# 2   5444812 Dollars  45456287   2%
# 3    454121 Dollars   4545454  23%
# 4   7878454 Dollars  87542131  45%

# %%
df.head(1)
# Out:
#    1    Lamtone         IT Services  2009  $11,757,018  6,482,465 Dollars  \
# 0  2  Stripfind  Financial Services  2010  $11,757,018   45412134 Dollars
#
#    45643434  30%
# 0  55454878  45%

# %%
df.head(7)
# Out:
#    1        Lamtone         IT Services  2009   $11,757,018   \
# 0  2      Stripfind  Financial Services  2010   $11,757,018
# 1  3  Concoperation              Health  2012   $11,757,018
# 2  4       Muttouch         IT Services  2013  $125,488,454
# 3  5       Techline              health  2018  $450,000,000
# 4  6        Cityace              health  2011   $45,105,454
# 5  7         kaylet              Health  2003    $5,465,451
# 6  8          helor              Health  2008  $354,787,821
#
#   6,482,465 Dollars  45643434     30%
# 0  45412134 Dollars  55454878     45%
# 1   45315481Dollars  54464546     12%
# 2   5444812 Dollars  45456287      2%
# 3    454121 Dollars   4545454     23%
# 4   7878454 Dollars  87542131     45%
# 5     445421Dollars   8564411  78500%
# 6   7854121 Dollars   4545451     42%

# %%
df.tail(3)
# Out:
#    1    Lamtone       IT Services  2009   $11,757,018  6,482,465 Dollars  \
# 5  7     kaylet            Health  2003    $5,465,451      445421Dollars
# 6  8      helor            Health  2008  $354,787,821    7854121 Dollars
# 7  9  serpaline  Government Serv.  2005   $87,875,315     485454 Dollars
#
#    45643434     30%
# 5   8564411  78500%
# 6   4545451     42%
# 7  47878512     20%

# %%
df.tail(7)
# Out:
#    1        Lamtone       IT Services  2009   $11,757,018  6,482,465 Dollars  \
# 1  3  Concoperation            Health  2012   $11,757,018    45315481Dollars
# 2  4       Muttouch       IT Services  2013  $125,488,454    5444812 Dollars
# 3  5       Techline            health  2018  $450,000,000     454121 Dollars
# 4  6        Cityace            health  2011   $45,105,454    7878454 Dollars
# 5  7         kaylet            Health  2003    $5,465,451      445421Dollars
# 6  8          helor            Health  2008  $354,787,821    7854121 Dollars
# 7  9      serpaline  Government Serv.  2005   $87,875,315     485454 Dollars
#
#    45643434     30%
# 1  54464546     12%
# 2  45456287      2%
# 3   4545454     23%
# 4  87542131     45%
# 5   8564411  78500%
# 6   4545451     42%
# 7  47878512     20%

# %%
df.tail()
# Out:
#    1    Lamtone       IT Services  2009   $11,757,018  6,482,465 Dollars  \
# 3  5   Techline            health  2018  $450,000,000     454121 Dollars
# 4  6    Cityace            health  2011   $45,105,454    7878454 Dollars
# 5  7     kaylet            Health  2003    $5,465,451      445421Dollars
# 6  8      helor            Health  2008  $354,787,821    7854121 Dollars
# 7  9  serpaline  Government Serv.  2005   $87,875,315     485454 Dollars
#
#    45643434     30%
# 3   4545454     23%
# 4  87542131     45%
# 5   8564411  78500%
# 6   4545451     42%
# 7  47878512     20%

# %%
df=pd.read_csv('E:\\new1\\Book3.csv',dtype={'ID': 'float64'})
df
# Out:
#     ID          Name             Industry  inception        Revenue  \
# 0  1.0        Lamtone         IT Services       2009   $11,757,018
# 1  2.0      Stripfind  Financial Services       2010   $11,757,018
# 2  3.0  Concoperation              Health       2012   $11,757,018
# 3  4.0       Muttouch         IT Services       2013  $125,488,454
# 4  5.0       Techline              health       2018  $450,000,000
# 5  6.0        Cityace              health       2011   $45,105,454
# 6  7.0         kaylet              Health       2003    $5,465,451
# 7  8.0          helor              Health       2008  $354,787,821
# 8  9.0      serpaline    Government Serv.       2005   $87,875,315
#
#             Expenses    Profit  Growth
# 0  6,482,465 Dollars  45643434     30%
# 1   45412134 Dollars  55454878     45%
# 2    45315481Dollars  54464546     12%
# 3    5444812 Dollars  45456287      2%
# 4     454121 Dollars   4545454     23%
# 5    7878454 Dollars  87542131     45%
# ...

# %%
df=pd.read_csv('E:\\new1\\Book3.csv',dtype={'ID': 'float64','Profit':'float64'})
df
# Out:
#     ID          Name             Industry  inception        Revenue  \
# 0  1.0        Lamtone         IT Services       2009   $11,757,018
# 1  2.0      Stripfind  Financial Services       2010   $11,757,018
# 2  3.0  Concoperation              Health       2012   $11,757,018
# 3  4.0       Muttouch         IT Services       2013  $125,488,454
# 4  5.0       Techline              health       2018  $450,000,000
# 5  6.0        Cityace              health       2011   $45,105,454
# 6  7.0         kaylet              Health       2003    $5,465,451
# 7  8.0          helor              Health       2008  $354,787,821
# 8  9.0      serpaline    Government Serv.       2005   $87,875,315
#
#             Expenses      Profit  Growth
# 0  6,482,465 Dollars  45643434.0     30%
# 1   45412134 Dollars  55454878.0     45%
# 2    45315481Dollars  54464546.0     12%
# 3    5444812 Dollars  45456287.0      2%
# 4     454121 Dollars   4545454.0     23%
# 5    7878454 Dollars  87542131.0     45%
# ...

# %%
df=pd.read_csv('E:\\new1\\Book3.csv')
df
# Out:
#    ID Date          Name             Industry  inception        Revenue  \
# 0   1  Yes        Lamtone         IT Services       2009   $11,757,018
# 1   2  Yes      Stripfind  Financial Services       2010   $11,757,018
# 2   3  Yes  Concoperation              Health       2012   $11,757,018
# 3   4  Yes       Muttouch         IT Services       2013  $125,488,454
# 4   5  Yes       Techline              health       2018  $450,000,000
# 5   6  Yes        Cityace              health       2011   $45,105,454
# 6   7  Yes         kaylet              Health       2003    $5,465,451
# 7   8  Yes          helor              Health       2008  $354,787,821
# 8   9  Yes      serpaline    Government Serv.       2005   $87,875,315
#
#             Expenses    Profit  Growth
# 0  6,482,465 Dollars  45643434     30%
# 1   45412134 Dollars  55454878     45%
# 2    45315481Dollars  54464546     12%
# 3    5444812 Dollars  45456287      2%
# 4     454121 Dollars   4545454     23%
# ...

# %%
df=pd.read_csv('E:\\new1\\Book3.csv',true_values = ['Yes'])
df
# Out:
#    ID  Date          Name             Industry  inception        Revenue  \
# 0   1  True        Lamtone         IT Services       2009   $11,757,018
# 1   2  True      Stripfind  Financial Services       2010   $11,757,018
# 2   3  True  Concoperation              Health       2012   $11,757,018
# 3   4  True       Muttouch         IT Services       2013  $125,488,454
# 4   5  True       Techline              health       2018  $450,000,000
# 5   6  True        Cityace              health       2011   $45,105,454
# 6   7  True         kaylet              Health       2003    $5,465,451
# 7   8  True          helor              Health       2008  $354,787,821
# 8   9  True      serpaline    Government Serv.       2005   $87,875,315
#
#             Expenses    Profit  Growth
# 0  6,482,465 Dollars  45643434     30%
# 1   45412134 Dollars  55454878     45%
# 2    45315481Dollars  54464546     12%
# 3    5444812 Dollars  45456287      2%
# 4     454121 Dollars   4545454     23%
# ...

# %%
df=pd.read_csv('E:\\new1\\Book3.csv', true_values=['Yes'],false_values=['no'])
df
# Out:
#    ID   Date          Name             Industry  inception        Revenue  \
# 0   1   True        Lamtone         IT Services       2009   $11,757,018
# 1   2   True      Stripfind  Financial Services       2010   $11,757,018
# 2   3  False  Concoperation              Health       2012   $11,757,018
# 3   4   True       Muttouch         IT Services       2013  $125,488,454
# 4   5   True       Techline              health       2018  $450,000,000
# 5   6  False        Cityace              health       2011   $45,105,454
# 6   7   True         kaylet              Health       2003    $5,465,451
# 7   8   True          helor              Health       2008  $354,787,821
# 8   9  False      serpaline    Government Serv.       2005   $87,875,315
#
#             Expenses    Profit  Growth
# 0  6,482,465 Dollars  45643434     30%
# 1   45412134 Dollars  55454878     45%
# 2    45315481Dollars  54464546     12%
# 3    5444812 Dollars  45456287      2%
# ...
