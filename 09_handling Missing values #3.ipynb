# %% [markdown]
# # handling missing values #3

# %%
import pandas as pd

# %%
df=pd.read_csv("E:\\new1\\Book4.csv")
df
# Out:
#    ID            Name           Companies    profit Growth
# 0   1         lamtone         IT Services   4521548    30%
# 1   2         stroven  Financial Services   4848445    20%
# 2   3  Concorporation              Health  16545610     7%
# 3   4             NaN         IT Services   5121551    NaN
# 4   5            mark                 NaN   4548512    21%

# %%
df.dropna()
# Out:
#    ID            Name           Companies    profit Growth
# 0   1         lamtone         IT Services   4521548    30%
# 1   2         stroven  Financial Services   4848445    20%
# 2   3  Concorporation              Health  16545610     7%

# %%
df.dropna(axis=1)
# Out:
#    ID    profit
# 0   1   4521548
# 1   2   4848445
# 2   3  16545610
# 3   4   5121551
# 4   5   4548512

# %%
df.dropna(how='any')
# Out:
#    ID            Name           Companies    profit Growth
# 0   1         lamtone         IT Services   4521548    30%
# 1   2         stroven  Financial Services   4848445    20%
# 2   3  Concorporation              Health  16545610     7%

# %%
df.dropna(axis=1,how='any')
# Out:
#    ID    profit
# 0   1   4521548
# 1   2   4848445
# 2   3  16545610
# 3   4   5121551
# 4   5   4548512

# %%
df.dropna(how='all')
# Out:
#    ID            Name           Companies    profit Growth
# 0   1         lamtone         IT Services   4521548    30%
# 1   2         stroven  Financial Services   4848445    20%
# 2   3  Concorporation              Health  16545610     7%
# 3   4             NaN         IT Services   5121551    NaN
# 4   5            mark                 NaN   4548512    21%

# %%
df.dropna(how='all')
# Out:
#    ID            Name           Companies    profit Growth
# 0   1         lamtone         IT Services   4521548    30%
# 1   2         stroven  Financial Services   4848445    20%
# 2   3  Concorporation              Health  16545610     7%
# 3   4             NaN         IT Services   5121551    NaN
# 4   5            mark                 NaN   4548512    21%

# %%
df=pd.read_csv("E:\\new1\\Book4.csv")
df
# Out:
#     ID            Name           Companies      profit Growth
# 0  1.0         lamtone         IT Services   4521548.0    30%
# 1  2.0         stroven  Financial Services   4848445.0    20%
# 2  3.0  Concorporation              Health  16545610.0     7%
# 3  4.0             NaN         IT Services   5121551.0    NaN
# 4  NaN             NaN                 NaN         NaN    NaN

# %%
df.dropna(how='all')
# Out:
#     ID            Name           Companies      profit Growth
# 0  1.0         lamtone         IT Services   4521548.0    30%
# 1  2.0         stroven  Financial Services   4848445.0    20%
# 2  3.0  Concorporation              Health  16545610.0     7%
# 3  4.0             NaN         IT Services   5121551.0    NaN

# %%
df.dropna(thresh=4)
# Out:
#     ID            Name           Companies      profit Growth
# 0  1.0         lamtone         IT Services   4521548.0    30%
# 1  2.0         stroven  Financial Services   4848445.0    20%
# 2  3.0  Concorporation              Health  16545610.0     7%

# %%
df=pd.read_csv("E:\\new1\\Book4.csv")
df
# Out:
#     ID            Name           Companies      profit Growth
# 0  1.0         lamtone         IT Services   4521548.0    30%
# 1  2.0         stroven  Financial Services   4848445.0    20%
# 2  3.0  Concorporation              Health  16545610.0     7%
# 3  4.0             NaN         IT Services   5121551.0    NaN
# 4  NaN             NaN                 NaN         NaN    NaN

# %%
df.dropna(subset=['ID'])
# Out:
#     ID            Name           Companies      profit Growth
# 0  1.0         lamtone         IT Services   4521548.0    30%
# 1  2.0         stroven  Financial Services   4848445.0    20%
# 2  3.0  Concorporation              Health  16545610.0     7%
# 3  4.0             NaN         IT Services   5121551.0    NaN

# %%
df.dropna(subset=['Name'])
# Out:
#     ID            Name           Companies      profit Growth
# 0  1.0         lamtone         IT Services   4521548.0    30%
# 1  2.0         stroven  Financial Services   4848445.0    20%
# 2  3.0  Concorporation              Health  16545610.0     7%

# %%
df.dropna(subset=['profit'])
# Out:
#     ID            Name           Companies      profit Growth
# 0  1.0         lamtone         IT Services   4521548.0    30%
# 1  2.0         stroven  Financial Services   4848445.0    20%
# 2  3.0  Concorporation              Health  16545610.0     7%
# 3  4.0             NaN         IT Services   5121551.0    NaN

# %%
df.dropna(inplace=True)
df
# Out:
#     ID            Name           Companies      profit Growth
# 0  1.0         lamtone         IT Services   4521548.0    30%
# 1  2.0         stroven  Financial Services   4848445.0    20%
# 2  3.0  Concorporation              Health  16545610.0     7%
